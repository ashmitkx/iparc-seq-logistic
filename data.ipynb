# %%
import json
import numpy as np
from matplotlib import pyplot as plt

# %%
inp = None
with open('./iparc-cata-simple/Task000.json') as f:
    inp = json.load(f)
a = np.array(inp[0]['input'])
b = np.array(inp[0]['output'])

plt.imshow(a)
plt.show()

plt.imshow(b)
plt.show()
